# %%
"""
User inputs the task, time, and importance level. 
The time is in minutes, while the importance is based on the word list:
Trivial, Low, Normal, High, or Critical
with them corresponding to the numbers 1, 2, 3, 5, 8 respectively.
These values are stored as the importance value for the task.
"""
# Out:
# '\nUser inputs the task, time, and importance level. \nThe time is in minutes, while the importance is based on the word list:\nTrivial, Low, Normal, High, or Critical\nwith them corresponding to the numbers 1, 2, 3, 5, 8 respectively.\nThese values are stored as the importance value for the task.\n'

# %%
# Example todo items, default weighted_values is 0 (NaN)
item_one = {
    "task": "take out trash",
    "time": 20,
    "importance": 3,
    "weighted_value": 0
}

item_two = {
    "task": "take recycling out",
    "time": 30,
    "importance": 5,
    "weighted_value": 0
}

# %%
# For display and input of importance level for each todo item
importance_scale = { 1: "Trivial", 2: "Low", 3: "Normal", 5: "High", 8: "Critical"}

# %%
# Gather the todo items in a single searchable list
items = [item_one, item_two]

# %%
print(items)
# Out:
# [{'task': 'take out trash', 'time': 20, 'importance': 3, 'weighted_value': 0}, {'task': 'take recycling out', 'time': 30, 'importance': 5, 'weighted_value': 0}]

# %%
# How to calculate and add the actual weighted_values of the todo items
for i, element in enumerate(items):
    weighted_value = element["importance"] / element["time"]
    #print(weighted_value)
    element["weighted_value"] = weighted_value

# %%
# Now todo list items have actual weighted_values values
print(items)
# Out:
# [{'task': 'take out trash', 'time': 20, 'importance': 3, 'weighted_value': 0.15}, {'task': 'take recycling out', 'time': 30, 'importance': 5, 'weighted_value': 0.16666666666666666}]

# %%
# Sorts the original todo items list in place, reverse=True for descending order 5, 4, 3, etc.
items.sort(key=lambda x: x["weighted_value"], reverse=True)
print(items)
# Out:
# [{'task': 'take recycling out', 'time': 30, 'importance': 5, 'weighted_value': 0.16666666666666666}, {'task': 'take out trash', 'time': 20, 'importance': 3, 'weighted_value': 0.15}]
